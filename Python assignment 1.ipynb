# %%
a="I have installed jypter notebook"
a
# Out:
# 'I have installed jypter notebook'

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question1.png")

# %%
a=[]
for i in range(2000,3201):
    if(i%7==0 and i%5!=0):
        a.append(i)
print(a)
# Out:
# [2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199]

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question2.png")

# %%
a=input("enter the first name:" )
b=input("enter the last name:"  )
a=a[::-1]
b=b[::-1]
print(a,b)
# Out:
# enter the first name:data
# enter the last name:scientist
# atad tsitneics

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question3.png")

# %%
R=int(input("enter the radius : "))
pi=3.14
V=4/3*pi*R**3
print("volume is :" ,V)
# Out:
# enter the radius : 12
# volume is : 7234.5599999999995

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question4.png")

# %%
#Write a program which accepts a sequence of comma-separated numbers from console and
#generate a list.

a=(input("enter the sequence of Number :"))
b=[]
b.append(a)
print(b)
# Out:
# enter the sequence of Number :1,2,3,4
# ['1,2,3,4']

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question5.png")

# %%
for i in range(1,11):
    if(i<=5):
        print(i*'*')
    if(i>=6):
        i=abs(i-10)
        print(i*'*')
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question6.png")

# %%
a=input("enter the string :")
a=a[::-1]
print(a)
# Out:
# enter the string :ineuron
# norueni

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question7.png")

# %%
a="WE,THE PEOPLE OF INDIA,"
b="having solemnly resolved to constitute India into a SOVEREIGN,"
c="SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC" 
d="and to secure to allits citizens"

print(a,"\n"," "*3,b,"\n\t"," ",c,"\n\t"," "*2,d)
# Out:
# WE,THE PEOPLE OF INDIA,
#      having solemnly resolved to constitute India into a SOVEREIGN,
# 	   SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 	    and to secure to allits citizens

# %%
from IPython.display import Image
Image(r"C:\Users\tushg\Desktop\INUERON\PYTHON Class\Question8.png")
